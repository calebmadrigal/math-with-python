# %%
# Imports and boilerplate to make graphs look better
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy
import wave
from IPython.display import Audio

def setup_graph(title='', x_label='', y_label='', fig_size=None, grid=True):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0], fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.grid(grid)

# %%
setup_graph(fig_size=(10,10))
#plt.plot(x, y, c=1, alpha=0.5)
x = np.linspace(-1, 1, 100)
exponents = np.linspace(-2, 2, 20)
y = [xi**exponents for xi in x]
_= plt.plot(x, y)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in power
#   """

# %%
setup_graph(title='x^e', x_label='real', y_label='imaginary', fig_size=(10,10))
#plt.plot(x, y, c=1, alpha=0.5)
x = np.linspace(-1, 1, 30)
exponents = np.linspace(-1, 1, 20)
for e in exponents:
    y = [xi**e for xi in x]
    _= plt.plot(x, y)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars

# %%
import matplotlib.cm as cm

setup_graph(title='x^e', x_label='real', y_label='imaginary', fig_size=(10,10))
x = np.linspace(-1, 1, 2)
colors = cm.rainbow(np.linspace(0, 1, len(x)))
exponents = np.linspace(-1, 1, 100)
for xi in x:
    for ei in exponents:
        v = complex(xi)**complex(ei)
        _ = plt.scatter(v.real, v.imag, s=5, color=colors)

# %%
import matplotlib.cm as cm

setup_graph(title='x^e', x_label='real', y_label='imaginary', fig_size=(10,10))
x = np.linspace(-2, 2, 20)
colors = cm.rainbow(np.linspace(0, 1, len(x)))
exponents = np.linspace(-2, 2, 500)
for xi in x:
    for ei in exponents:
        v = complex(xi)**complex(ei)
        _ = plt.scatter(v.real, v.imag, s=2, color=colors)

# %%
setup_graph(fig_size=(12,6))
x = np.linspace(0, 1, 100)
y = np.sin(1 * 2*np.pi*x)
_= plt.plot(x, y)

# %%
setup_graph(fig_size=(12,6))
x = np.linspace(0, 1, 100)
y = np.sin(1 * 2*np.pi*x) * np.sin(1 * 2*np.pi*x)
_= plt.plot(x, y)

# %%
setup_graph(fig_size=(12,6))
x = np.linspace(0, 1, 100)
y = np.sin(1 * 2*np.pi*x) + np.sin(1 * 2*np.pi*x)
_= plt.plot(x, y)

# %%
setup_graph(fig_size=(12,6))
x = np.linspace(0, 1, 100)
y = np.sin(2 * 2*np.pi*x)
_= plt.plot(x, y)

# %%
setup_graph(fig_size=(12,6))
x = np.linspace(0, 1, 100)
y = np.sin(2 * 2*np.pi*x) * np.sin(2 * 2*np.pi*x)
_= plt.plot(x, y)

# %%
setup_graph(fig_size=(10,10))
#plt.plot(x, y, c=1, alpha=0.5)
x = np.linspace(-2.5, 2, 100)
y = [complex(xi)**complex(xi) for xi in x]
_= plt.plot(x, y)
# Out:
# /usr/local/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
setup_graph(fig_size=(10,10))
#plt.plot(x, y, c=1, alpha=0.5)
x = np.linspace(-4.5, 1, 1000)
y = [complex(xi)**complex(xi) for xi in x]
_= plt.plot([i.real for i in y], [i.imag for i in y])
